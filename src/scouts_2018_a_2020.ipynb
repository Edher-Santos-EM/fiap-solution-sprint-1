# %%
import pandas as pd

# %%
times = pd.read_csv("times_ids.csv")

# %%
medias_2018 = pd.read_csv("2018-medias-jogadores.csv")

# %%
medias_2018.insert(0, "ano", 2018, True)

# %%
medias_2019 = pd.read_csv("2019-medias-jogadores.csv")

# %%
medias_2019.insert(0, "ano", 2019, True)

# %%
medias_2020 = pd.read_csv("2020-medias-jogadores.csv")

# %%
medias_2020.insert(0, "ano", 2020, True)

# %%
medias_2018 = medias_2018[['ano','player_nickname', 'player_id', 'player_team', 'player_position','score_mean']]

# %%
medias_2019 = medias_2019[['ano','player_nickname', 'player_id', 'player_team', 'player_position','score_mean']]

# %%
medias_2020 = medias_2020[['ano','player_nickname', 'player_id', 'player_team', 'player_position','score_mean']]

# %%
medias_2018_2020 = pd.concat([medias_2018, medias_2019, medias_2020])

# %%
medias_2018_2020.update(medias_2018_2020.loc[medias_2018_2020.player_team == 'Bragantino'].replace('Bragantino', 280))

# %%
medias_2018_2020
# Out:
#         ano  player_nickname  player_id player_team player_position  \
# 0    2018.0            Apodi    51042.0         315             lat
# 1    2018.0          Arthur     80337.0         315             ata
# 2    2018.0          Sidcley    86764.0         264             lat
# 3    2018.0     Róger Guedes    89898.0         282             ata
# 4    2018.0  Vinicius Junior    99535.0         262             ata
# ..      ...              ...        ...         ...             ...
# 594  2020.0          Derick    109830.0         277             zag
# 595  2020.0            Renan   109963.0         275             lat
# 596  2020.0        Christian   110210.0         266             ata
# 597  2020.0      João Victor   110258.0         293             lat
# 598  2020.0  Gustavo Mantuan   110270.0         264             mei
#
#      score_mean
# 0      3.845455
# 1      4.700000
# 2      6.070000
# 3     10.627273
# 4      6.609091
# ..          ...
# 594    0.000000
# 595   -1.100000
# 596    0.000000
# 597    1.000000
# 598    2.033333
#
# [1717 rows x 6 columns]

# %%
medias_2018_2020.ano = medias_2018_2020.ano.astype('int64', copy=False)

# %%
medias_2018_2020.player_id = medias_2018_2020.player_id.astype('int64', copy=False)

# %%
medias_2018_2020.player_team = medias_2018_2020.player_team.astype('int64', copy=False)

# %%
medias_2018_2020
# Out:
#       ano  player_nickname  player_id  player_team player_position  score_mean
# 0    2018            Apodi      51042          315             lat    3.845455
# 1    2018          Arthur       80337          315             ata    4.700000
# 2    2018          Sidcley      86764          264             lat    6.070000
# 3    2018     Róger Guedes      89898          282             ata   10.627273
# 4    2018  Vinicius Junior      99535          262             ata    6.609091
# ..    ...              ...        ...          ...             ...         ...
# 594  2020          Derick      109830          277             zag    0.000000
# 595  2020            Renan     109963          275             lat   -1.100000
# 596  2020        Christian     110210          266             ata    0.000000
# 597  2020      João Victor     110258          293             lat    1.000000
# 598  2020  Gustavo Mantuan     110270          264             mei    2.033333
#
# [1717 rows x 6 columns]

# %%
medias_2018_2020.loc[~medias_2018_2020["player_team"].isin(times['id'])]
# Out:
#       ano    player_nickname  player_id  player_team player_position  \
# 21   2018              Reina      70118          204             mei
# 53   2018    Juninho Quixadá      71787          204             ata
# 84   2018            Arnaldo      78497          204             lat
# 86   2018         João Lucas      86740          204             lat
# 105  2018             Edinho      37792          204             mei
# 112  2018        Tiago Alves      51495          204             zag
# 198  2018   Leandro Carvalho      88669          204             ata
# 219  2018          Eder Luis      38508          204             ata
# 244  2018     Felipe Azevedo      60825          204             ata
# 279  2018            Wescley      70925          204             mei
# 289  2018            Juninho      71937          204             mei
# 291  2018            Éverson      72294          204             gol
# 292  2018        Luiz Otávio      72359          204             zag
# 294  2018      Samuel Xavier      73384          204             lat
# 311  2020     Fabrício Bruno      90768          280             zag
# 340  2018            Calyson      82630          204             mei
# 343  2018              Valdo      84509          204             zag
# 353  2018         Richardson      86536          204             mei
# 373  2020      Matheus Jesus      95335          280             mei
# 385  2018             Arthur      92171          204             ata
# 396  2020            Robinho      97461          280             ata
# 420  2018     Felipe Jonatan     101708          204             lat
# 311  2020     Fabrício Bruno      90768          280             zag
# 373  2020      Matheus Jesus      95335          280             mei
# 396  2020            Robinho      97461          280             ata
# 438  2020       Luan Cândido     100848          280             lat
# 447  2020            Chrigor     101398          280             ata
# 5    2020        Júlio César      38133          280             gol
# 52   2020              Ytalo      53148          280             ata
# 59   2020             Ligger      61141          280             zag
# 62   2020             Edimar      62024          280             lat
# 123  2020    Uillian Correia      72007          280             mei
# 240  2020  Lucas Evangelista      84674          280             mei
# 249  2020     Ricardo Ryller      85856          280             mei
# 251  2020             Morato      86227          280             ata
# 286  2020            Aderlan      88423          280             lat
# 290  2020            Barreto      89224          280             mei
# 311  2020     Fabrício Bruno      90768          280             zag
# 326  2020         Leandrinho      91702          280             ata
# 338  2020               Raul      92496          280             mei
# 339  2020          Claudinho      92630          280             ata
# 345  2020    Wesley Pionteck      93376          280             ata
# 348  2020      Bruno Tubarão      93637          280             mei
# 352  2020            Cleiton      93882          280             gol
# 373  2020      Matheus Jesus      95335          280             mei
# 382  2020              Artur      95799          280             ata
# 396  2020            Robinho      97461          280             ata
# 398  2020          Léo Ortiz      97867          280             zag
# 414  2020             Cuello      98909          280             mei
# 438  2020       Luan Cândido     100848          280             lat
# 447  2020            Chrigor     101398          280             ata
# 450  2020    Thonny Anderson     101484          280             mei
# 461  2020         Alerrandro     101715          280             ata
# 515  2020       Luis Phelipe     104500          280             ata
# 524  2020           Weverton     104625          280             lat
# 531  2020            Hurtado     105301          280             ata
# 551  2020             Realpe     106299          280             zag
# 588  2020           Weverson     109426          280             lat
#
#      score_mean
# 21    -0.480000
# 53     4.450000
# 84     2.881818
# 86     3.316667
# 105    0.135294
# 112    3.626087
# 198    4.842105
# 219    0.530769
# 244    2.200000
# 279    2.518182
# 289    4.033333
# 291    5.541176
# 292    4.390000
# 294    3.758333
# 311    0.300000
# 340    2.000000
# 343    3.526667
# 353    3.277778
# 373    1.077778
# 385    2.175000
# 396    1.560000
# 420    4.907143
# 311    0.300000
# 373    1.077778
# 396    1.560000
# 438   -3.000000
# 447    2.400000
# 5      2.285714
# 52     2.380000
# 59     1.836364
# 62     1.225000
# 123   -0.671429
# 240    4.240000
# 249    1.268750
# 251    0.180000
# 286    2.387500
# 290    0.725000
# 311    0.300000
# 326    0.966667
# 338    6.144444
# 339    5.053333
# 345    0.700000
# 348    2.621429
# 352   -1.637500
# 373    1.077778
# 382    3.186667
# 396    1.560000
# 398    2.747059
# 414    2.500000
# 438   -3.000000
# 447    2.400000
# 450    1.900000
# 461    5.800000
# 515    2.888889
# 524    0.075000
# 531    0.300000
# 551    0.660000
# 588   -1.033333

# %%
medias_2018_2020.insert(2, "ClubeID", medias_2018_2020["player_team"].map(lambda x: 'Ceará' if x == 204 else 'Bragantino' if x == 280 else times.loc[times['id'] == x]['nome.cartola'].values[0]), False)

# %%
medias_2018_2020 = medias_2018_2020.rename(columns={"player_nickname": "Apelido", "player_id": "AtletaID", "player_position": "Posicao", "score_mean": "Pontos"})

# %%
medias_2018_2020[['ano', 'Apelido', 'AtletaID', 'ClubeID', 'Posicao', 'Pontos']]
# Out:
#       ano          Apelido  AtletaID      ClubeID Posicao     Pontos
# 0    2018            Apodi     51042  Chapecoense     lat   3.845455
# 1    2018          Arthur      80337  Chapecoense     ata   4.700000
# 2    2018          Sidcley     86764  Corinthians     lat   6.070000
# 3    2018     Róger Guedes     89898  Atlético-MG     ata  10.627273
# 4    2018  Vinicius Junior     99535     Flamengo     ata   6.609091
# ..    ...              ...       ...          ...     ...        ...
# 594  2020          Derick     109830       Santos     zag   0.000000
# 595  2020            Renan    109963    Palmeiras     lat  -1.100000
# 596  2020        Christian    110210   Fluminense     ata   0.000000
# 597  2020      João Victor    110258  Atlético-PR     lat   1.000000
# 598  2020  Gustavo Mantuan    110270  Corinthians     mei   2.033333
#
# [1717 rows x 6 columns]
